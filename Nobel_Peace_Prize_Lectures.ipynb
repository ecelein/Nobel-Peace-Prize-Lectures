# %% [markdown]
# ### Installing, Importing and Preprocessing¶

# %%
# Import spacy
import spacy

# Install English language model
# !spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------------------- -------------- 8.1/12.8 MB 41.8 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ecede\anaconda3\envs\myenvironment\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Import os to upload documents and metadata
import os

# Load spaCy visualizer
from spacy import displacy

# Import pandas DataFrame packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# Import graphing package
import plotly.express as px

# %%
#Load main dataset
nobel_df = pd.read_csv("nobel.csv")
nobel_df.head()
# Out:
#                                             Filename  \
# 0  The Nobel Peace Prize Lecture 2013_Organisatio...
# 1  The Nobel Peace Prize Lecture 2014_Kailash Sat...
# 2  The Nobel Peace Prize Lecture 2014_Malala Yous...
# 3  The Nobel Peace Prize Lecture 2015_National Di...
# 4  The Nobel Peace Prize Lecture 2016_Juan Manuel...
#
#                                             Document
# 0  Your Majesties,\nYour Royal Highness,\nDisting...
# 1  (My dear children of the world …)\n\nYour Maje...
# 2  Bismillah hir rahman ir rahim.\nIn the name of...
# 3  His Majesty,\nTheir Highnesses,\nThe respected...
# 4  Your Majesties; Your Royal Highnesses; disting...

# %%
# Load metadata
metadata_df = pd.read_csv("metadata.csv")
metadata_df.head()
# Out:
#                                             Filename  \
# 0  The Nobel Peace Prize Lecture 2013_Organisatio...
# 1  The Nobel Peace Prize Lecture 2014_Kailash Sat...
# 2  The Nobel Peace Prize Lecture 2014_Malala Yous...
# 3  The Nobel Peace Prize Lecture 2015_National Di...
# 4  The Nobel Peace Prize Lecture 2016_Juan Manuel...
#
#                                       Prize Laureate  Year Awarded  \
# 0  Organisation for the Prohibition of Chemical W...          2013
# 1                                  Kailash Satyarthi          2014
# 2                                   Malala Yousafzai          2014
# 3                          National Dialogue Quartet          2015
# 4                                 Juan Manuel Santos          2016
#
#   Place of Birth/Place of Foundation  Date of Birth/Date of Foundation  \
# 0                                NaN                              1997
# 1                              India                              1954
# 2                           Pakistan                              1997
# 3                            Tunisia                              2013
# 4                           Colombia                              1951
#
#   Prize Share
# 0         1/1
# 1         1/2
# 2         1/2
# 3         1/1
# 4         1/1

# %%
# Merge metadata and lectures into new DataFrame
# Will only keep rows where both lectures and metadata are present
final_nobel_df = metadata_df.merge(nobel_df,on='Filename')

# %%
# Print DataFrame
final_nobel_df.head()
# Out:
#                                             Filename  \
# 0  The Nobel Peace Prize Lecture 2013_Organisatio...
# 1  The Nobel Peace Prize Lecture 2014_Kailash Sat...
# 2  The Nobel Peace Prize Lecture 2014_Malala Yous...
# 3  The Nobel Peace Prize Lecture 2015_National Di...
# 4  The Nobel Peace Prize Lecture 2016_Juan Manuel...
#
#                                       Prize Laureate  Year Awarded  \
# 0  Organisation for the Prohibition of Chemical W...          2013
# 1                                  Kailash Satyarthi          2014
# 2                                   Malala Yousafzai          2014
# 3                          National Dialogue Quartet          2015
# 4                                 Juan Manuel Santos          2016
#
#   Place of Birth/Place of Foundation  Date of Birth/Date of Foundation  \
# 0                                NaN                              1997
# 1                              India                              1954
# 2                           Pakistan                              1997
# 3                            Tunisia                              2013
# 4                           Colombia                              1951
#
#   Prize Share                                           Document
# 0         1/1  Your Majesties,\nYour Royal Highness,\nDisting...
# 1         1/2  (My dear children of the world …)\n\nYour Maje...
# 2         1/2  Bismillah hir rahman ir rahim.\nIn the name of...
# 3         1/1  His Majesty,\nTheir Highnesses,\nThe respected...
# 4         1/1  Your Majesties; Your Royal Highnesses; disting...

# %% [markdown]
# ### Text Enrichment with spaCy

# %%
# Load nlp pipeline
nlp = spacy.load('en_core_web_sm')

# %%
#Define example sentence
sentence = "This is 'an' example? sentence"

# Call the nlp model on the sentence
doc = nlp(sentence)

# %%
# Define a function that runs the nlp pipeline on any given input text
def process_text(text):
    return nlp(text)

# %%
# Apply the function to the "Document" column, so that the nlp pipeline is called on each lecture
final_nobel_df['Doc'] = final_nobel_df['Document'].apply(process_text)

# %% [markdown]
# ### Tokenization

# %%
# Define a function to retrieve tokens from a doc object
def get_token(doc):
    return [(token.text) for token in doc]

# %%
# Run the token retrieval function on the doc objects in the dataframe
final_nobel_df['Tokens'] = final_nobel_df['Doc'].apply(get_token)
final_nobel_df.head()
# Out:
#                                             Filename  \
# 0  The Nobel Peace Prize Lecture 2013_Organisatio...
# 1  The Nobel Peace Prize Lecture 2014_Kailash Sat...
# 2  The Nobel Peace Prize Lecture 2014_Malala Yous...
# 3  The Nobel Peace Prize Lecture 2015_National Di...
# 4  The Nobel Peace Prize Lecture 2016_Juan Manuel...
#
#                                       Prize Laureate  Year Awarded  \
# 0  Organisation for the Prohibition of Chemical W...          2013
# 1                                  Kailash Satyarthi          2014
# 2                                   Malala Yousafzai          2014
# 3                          National Dialogue Quartet          2015
# 4                                 Juan Manuel Santos          2016
#
#   Place of Birth/Place of Foundation  Date of Birth/Date of Foundation  \
# 0                                NaN                              1997
# 1                              India                              1954
# 2                           Pakistan                              1997
# 3                            Tunisia                              2013
# 4                           Colombia                              1951
#
#   Prize Share                                           Document  \
# 0         1/1  Your Majesties,\nYour Royal Highness,\nDisting...
# 1         1/2  (My dear children of the world …)\n\nYour Maje...
# 2         1/2  Bismillah hir rahman ir rahim.\nIn the name of...
# 3         1/1  His Majesty,\nTheir Highnesses,\nThe respected...
# 4         1/1  Your Majesties; Your Royal Highnesses; disting...
#
#                                                  Doc  \
# 0  (Your, Majesties, ,, \n, Your, Royal, Highness...
# 1  ((, My, dear, children, of, the, world, …, ), ...
# 2  (Bismillah, hir, rahman, ir, rahim, ., \n, In,...
# 3  (His, Majesty, ,, \n, Their, Highnesses, ,, \n...
# 4  (Your, Majesties, ;, Your, Royal, Highnesses, ...
#
#                                               Tokens
# 0  [Your, Majesties, ,, \n, Your, Royal, Highness...
# 1  [(, My, dear, children, of, the, world, …, ), ...
# 2  [Bismillah, hir, rahman, ir, rahim, ., \n, In,...
# 3  [His, Majesty, ,, \n, Their, Highnesses, ,, \n...
# 4  [Your, Majesties, ;, Your, Royal, Highnesses, ...

# %%
tokens = final_nobel_df[['Document', 'Tokens']].copy()
tokens.head()
# Out:
#                                             Document  \
# 0  Your Majesties,\nYour Royal Highness,\nDisting...
# 1  (My dear children of the world …)\n\nYour Maje...
# 2  Bismillah hir rahman ir rahim.\nIn the name of...
# 3  His Majesty,\nTheir Highnesses,\nThe respected...
# 4  Your Majesties; Your Royal Highnesses; disting...
#
#                                               Tokens
# 0  [Your, Majesties, ,, \n, Your, Royal, Highness...
# 1  [(, My, dear, children, of, the, world, …, ), ...
# 2  [Bismillah, hir, rahman, ir, rahim, ., \n, In,...
# 3  [His, Majesty, ,, \n, Their, Highnesses, ,, \n...
# 4  [Your, Majesties, ;, Your, Royal, Highnesses, ...

# %% [markdown]
# ### Lemmatization

# %%
# Define a function to retrieve lemmas from a doc object
def get_lemma(doc):
    return [(token.lemma_) for token in doc]

# Run the lemma retrieval function on the doc objects in the dataframe
final_nobel_df['Lemmas'] = final_nobel_df['Doc'].apply(get_lemma)

# %%
print(f'"Peace" appears in the text tokens column ' + str(final_nobel_df['Tokens'].apply(lambda x: x.count('peace')).sum()) + ' times.')
print(f'"Peace" appears in the lemmas column ' + str(final_nobel_df['Lemmas'].apply(lambda x: x.count('peace')).sum()) + ' times.')
# Out:
# "Peace" appears in the text tokens column 151 times.
# "Peace" appears in the lemmas column 155 times.

# %% [markdown]
# ### Part of Speech Tagging

# %%
# Define a function to retrieve lemmas from a doc object
def get_pos(doc):
    #Return the coarse- and fine-grained part of speech text for each token in the doc
    return [(token.pos_, token.tag_) for token in doc]

# Define a function to retrieve parts of speech from a doc object
final_nobel_df['POS'] = final_nobel_df['Doc'].apply(get_pos)

# %%
# Define function to extract proper nouns from Doc object
def extract_proper_nouns(doc):
    return [token.text for token in doc if token.pos_ == 'PROPN']

# Apply function to Doc column and store resulting proper nouns in new column
final_nobel_df['Proper_Nouns'] = final_nobel_df['Doc'].apply(extract_proper_nouns)

# %%
list(final_nobel_df.loc[[5, 10], 'Proper_Nouns'])
# Out:
# [['Majesties',
#   'Nobel',
#   'Committee',
#   'Esteemed',
#   'Nobel',
#   'Peace',
#   'Prize',
#   'International',
#   'Campaign',
#   'Nuclear',
#   'Weapons',
#   'Nobel',
#   'Committee',
#   'Red',
#   'Cross',
#   'Red',
#   'Crescent',
#   'UN',
#   'Ours',
#   'Nobel',
#   'Laureate',
#   'William',
#   'Faulkner',
#   'Armageddon',
#   'blocs',
#   'Cold',
#   'War',
#   'Cold',
#   'War',
#   'Fear',
#   'Earth',
#   'Faulkner',
#   'Nobel',
#   'ICAN',
#   'International',
#   'Physicians',
#   'Prevention',
#   'Nuclear',
#   'War',
#   'Man',
#   'Cold',
#   'War',
#   'Iraq',
#   'Iran',
#   'Kashmir',
#   'North',
#   'Korea',
#   'Nobel',
#   'Peace',
#   'Laureate',
#   'Martin',
#   'Luther',
#   'King',
#   'Jr',
#   'ICAN',
#   'Setsuko',
#   'Thurlow',
#   'hibakusha',
#   'ICAN',
#   'UN',
#   'Treaty',
#   'Prohibition',
#   'Nuclear',
#   'Weapons',
#   'Treaty',
#   'Prohibition',
#   'Nuclear',
#   'Weapons',
#   'United',
#   'States',
#   'Russia',
#   'Britain',
#   'France',
#   'China',
#   'India',
#   'Pakistan',
#   'Armageddon',
#   'Israel',
#   'North',
#   'Korea',
#   'ruin',
#   'Treaty',
#   'Prohibition',
#   'Nuclear',
#   'Weapons',
#   'Treaty',
#   'States',
#   'Setsuko',
#   'Thurlow',
#   'Majesties',
#   'Nobel',
#   'Committee',
#   'Beatrice',
#   'hibakusha',
#   'Hiroshima',
#   'Nagasaki',
#   'Moruroa',
#   'Ekker',
#   'Semipalatinsk',
#   'Maralinga',
#   'Bikini',
#   'Hiroshima',
#   'Nagasaki',
#   'United',
#   'States',
#   'Hiroshima',
#   'God',
#   'Hiroshima',
#   'Eiji',
#   'hibakusha',
#   'Hiroshima',
#   'Nagasaki',
#   'July',
#   'Treaty',
#   'Prohibition',
#   'Nuclear',
#   'Weapons',
#   'hibakusha',
#   'Heed',
#   'Hiroshima',
#   'Tonight',
#   'Oslo'],
#  ['Nobel',
#   'Committee',
#   'October',
#   'Mom',
#   'Nobel',
#   'Prize',
#   '-That',
#   '<',
#   '…',
#   'disarmament',
#   'Peace',
#   'Nobel',
#   'Academy',
#   'Science',
#   'Andrei',
#   'Sakharov',
#   'Elena',
#   'Bonner',
#   'Thursday',
#   'December',
#   'Sakharov',
#   'Chechen',
#   'Ministry',
#   'Defence',
#   'Commander',
#   'Shcherbakov',
#   'War',
#   'Chechnya',
#   'Boeing',
#   'MH17',
#   'Russia',
#   'Ukraine',
#   'Russia',
#   'Ukraine',
#   'Chechen',
#   'Novaya',
#   'Gazeta',
#   'Major',
#   'Izmajlov',
#   'Nobel',
#   'Peace',
#   'Prize',
#   'Moscow',
#   'Kremlin',
#   'April',
#   'Politburo',
#   'Afghanistan',
#   'Mikhail',
#   'Gorbachev',
#   'Europe',
#   'Eastern',
#   'Ukraine',
#   'President',
#   'Belarus',
#   'Lukashenko',
#   'Middle',
#   'East',
#   'European',
#   'Union',
#   'Middle',
#   'East',
#   'Minsk',
#   'August',
#   'November',
#   'Stalin',
#   'Russia',
#   'Alexei',
#   'Navalny',
#   'CEO',
#   'Navalny',
#   'Novaya',
#   'Gazeta',
#   'Russia',
#   'Russia',
#   'Sakharov',
#   'Russia',
#   'Prosecutor',
#   'General',
#   'Memorial',
#   'Memorial',
#   'Stalin',
#   'Prosecutor',
#   'Memorial',
#   'FSB',
#   'Stalin',
#   'Memorial',
#   'Sakharov',
#   'Memorial',
#   'Memorial',
#   'Treasury',
#   'Novaya',
#   'Gazeta',
#   'Ekho',
#   'Moscow',
#   'Dozhd',
#   'Rain',
#   'TV',
#   'SMA',
#   'Russia',
#   'NGOs',
#   'Russia',
#   'September',
#   'St.',
#   'Petersburg',
#   'Stettin',
#   'Germany',
#   'Bolsheviks',
#   'Russia',
#   'Sikorsky',
#   'Zvorykin',
#   'Frank',
#   'Ilyin',
#   'Pitirim',
#   'Sorokin',
#   'Oberbürgermeister',
#   'Haken',
#   'Nikolai',
#   'Berdyaev',
#   'Russia',
#   'Orkhan',
#   'Dzhemal',
#   'Kirill',
#   'Radchenko',
#   'Alexander',
#   'Rastorguyev',
#   'Central',
#   'African',
#   'Republic',
#   'Orkhan',
#   'Ira',
#   'Gordienko',
#   'Novaya',
#   'Gazeta',
#   'June',
#   'UN',
#   'Secretary',
#   'General',
#   'António',
#   'Guterres',
#   'Robert',
#   'Capa',
#   'Novaya',
#   'Gazeta',
#   'Igor',
#   'Domnikov',
#   'Yuri',
#   'Shchekotschikhin',
#   'Anna',
#   'Politkovskaya',
#   'Anastasija',
#   'Baburova',
#   'Stas',
#   'Markelov',
#   'Natasha',
#   'Estemirova',
#   'Anna',
#   'Politkovskaya',
#   'Novaya',
#   'Gazeta',
#   'English',
#   'PS',
#   'Maria',
#   'Ressa']]

# %% [markdown]
# ### Named Entity Recognition

# %%
# Define function to extract named entities from doc objects
def extract_named_entities(doc):
    return [ent.label_ for ent in doc.ents]

# Apply function to Doc column and store resulting named entities in new column
final_nobel_df['Named_Entities'] = final_nobel_df['Doc'].apply(extract_named_entities)
final_nobel_df['Named_Entities']
# Out:
# 0     [ORG, ORG, ORG, ORG, GPE, DATE, PERSON, ORG, O...
# 1     [ORG, ORG, PERSON, PERSON, PERSON, LOC, LOC, L...
# 2     [ORG, PERSON, ORG, DATE, DATE, ORG, ORG, PRODU...
# 3     [PERSON, ORG, WORK_OF_ART, ORG, ORG, ORG, ORG,...
# 4     [ORG, ORG, GPE, DATE, NORP, DATE, DATE, DATE, ...
# 5     [ORG, ORG, DATE, DATE, WORK_OF_ART, CARDINAL, ...
# 6     [DATE, GPE, GPE, ORG, CARDINAL, GPE, DATE, LOC...
# 7     [ORG, ORG, ORG, PERSON, LOC, ORG, GPE, DATE, D...
# 8     [ORG, ORG, PERSON, ORG, ORG, GPE, GPE, NORP, N...
# 9     [DATE, QUANTITY, GPE, DATE, DATE, GPE, GPE, GP...
# 10    [ORG, TIME, DATE, WORK_OF_ART, CARDINAL, WORK_...
# 11    [ORG, GPE, ORG, GPE, GPE, ORG, GPE, PERSON, GP...
# 12    [ORG, PERSON, ORG, ORG, DATE, WORK_OF_ART, PER...
# 13    [PERSON, ORG, GPE, DATE, NORP, WORK_OF_ART, OR...
# 14    [ORG, WORK_OF_ART, DATE, ORG, ORG, NORP, PERSO...
# 15    [PERSON, ORG, ORG, WORK_OF_ART, WORK_OF_ART, W...
# Name: Named_Entities, dtype: object

# %%
# Define function to extract text tagged with named entities from doc objects
def extract_named_entities(doc):
    return [ent for ent in doc.ents]

# Apply function to Doc column and store resulting text in new column
final_nobel_df['NE_Words'] = final_nobel_df['Doc'].apply(extract_named_entities)
final_nobel_df['NE_Words']
# Out:
# 0     [(Your, Royal, Highness), (the, Norwegian, Nob...
# 1     [(Excellencies), (the, Norwegian, Nobel, Commi...
# 2     [(Bismillah), (rahman, ir, rahim), (the, Norwe...
# 3     [(Majesty), (the, Nobel, Committee), (Ladies, ...
# 4     [(Royal, Highnesses), (the, Norwegian, Nobel, ...
# 5     [(the, Norwegian, Nobel, Committee), (Esteemed...
# 6     [(6, October, 1996), (Lemera), (the, Democrati...
# 7     [(Excellencies), (the, Committee), (The, Nobel...
# 8     [(the, Norwegian, Nobel, Committee), (Fellow, ...
# 9     [(April, 10th, ,, 1815), (six, thousand, miles...
# 10    [(the, Nobel, Committee), (the, morning), (Oct...
# 11    [(the, Norwegian, Nobel, Committee), (Jamal, K...
# 12    [(Royal, Majesties), (Royal, Highnesses), (Hon...
# 13    [(Royal, Highnesses), (the, Norwegian, Nobel, ...
# 14    [(the, Norwegian, Nobel, Committee), (the, Nob...
# 15    [(Royal, Highnesses), (Excellencies), (the, No...
# Name: NE_Words, dtype: object

# %%
# Extract the first Doc object
doc = final_nobel_df['Doc'][1]

# Visualize named entity tagging in a single paper
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">(My dear children of the world …)<br><br>Your Majesties, Your Royal Highnesses,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Excellencies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , distinguished members of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Norwegian Nobel Committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , dear brother
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tom Harkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , brothers and sisters, and my dear daughter
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Malala
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br><br><br>(From this podium of peace and humanity, I am deeply honoured to recite a mantra from the ancient texts of wisdom,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vedas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br><br>This mantra carries a prayer, an aspiration and a resolve that has the potential to liberate humanity from all man-made crises.)<br><br><br>(Let’s walk together. In the pursuit of global progress, not a single person should be left out or left behind in any corner of the world, from
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     West
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , from
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     South
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  to
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .)<br><br><br>(Let’s speak together, let our minds come together! Learning from the experiences of our ancestors, let us together create knowledge for all that benefits all.)<br><br><br>(I bow to my late parents, to my motherland
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and to the mother earth.)<br><br><br>(With a warm heart I recall how
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of times, I have been liberated, each time I have freed a child from slavery. In the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  smile of freedom on their beautiful faces, I see the Gods smiling.)<br><br><br>(I give the biggest credit of this honour to my movement’s
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kaalu Kumar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Dhoom Das and Adarsh Kishore from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Iqbal Masih
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Pakistan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  who made the supreme sacrifice for protecting the freedom and dignity of children. I humbly accept this award on behalf of all such martyrs, my fellow activists across the world and my countrymen.)<br><br><br>(My journey from the great land of Lord
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Buddha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Guru Nanak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mahatma Gandhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ;
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is a connect between the
# <mark class="entity" style="background: #e4e7d2; padding: 0.

# %%
final_nobel_df.to_csv('final_nobel_lectures.csv', index=False)
final_nobel_df.head()
# Out:
#                                             Filename  \
# 0  The Nobel Peace Prize Lecture 2013_Organisatio...
# 1  The Nobel Peace Prize Lecture 2014_Kailash Sat...
# 2  The Nobel Peace Prize Lecture 2014_Malala Yous...
# 3  The Nobel Peace Prize Lecture 2015_National Di...
# 4  The Nobel Peace Prize Lecture 2016_Juan Manuel...
#
#                                       Prize Laureate  Year Awarded  \
# 0  Organisation for the Prohibition of Chemical W...          2013
# 1                                  Kailash Satyarthi          2014
# 2                                   Malala Yousafzai          2014
# 3                          National Dialogue Quartet          2015
# 4                                 Juan Manuel Santos          2016
#
#   Place of Birth/Place of Foundation  Date of Birth/Date of Foundation  \
# 0                                NaN                              1997
# 1                              India                              1954
# 2                           Pakistan                              1997
# 3                            Tunisia                              2013
# 4                           Colombia                              1951
#
#   Prize Share                                           Document  \
# 0         1/1  Your Majesties,\nYour Royal Highness,\nDisting...
# 1         1/2  (My dear children of the world …)\n\nYour Maje...
# 2         1/2  Bismillah hir rahman ir rahim.\nIn the name of...
# 3         1/1  His Majesty,\nTheir Highnesses,\nThe respected...
# 4         1/1  Your Majesties; Your Royal Highnesses; disting...
#
#                                                  Doc  \
# 0  (Your, Majesties, ,, \n, Your, Royal, Highness...
# 1  ((, My, dear, children, of, the, world, …, ), ...
# 2  (Bismillah, hir, rahman, ir, rahim, ., \n, In,...
# 3  (His, Majesty, ,, \n, Their, Highnesses, ,, \n...
# 4  (Your, Majesties, ;, Your, Royal, Highnesses, ...
#
#                                               Tokens  \
# 0  [Your, Majesties, ,, \n, Your, Royal, Highness...
# 1  [(, My, dear, children, of, the, world, …, ), ...
# 2  [Bismillah, hir, rahman, ir, rahim, ., \n, In,...
# 3  [His, Majesty, ,, \n, Their, Highnesses, ,, \n...
# 4  [Your, Majesties, ;, Your, Royal, Highnesses, ...
#
#                                               Lemmas  \
# 0  [your, Majesties, ,, \n, your, Royal, Highness...
# 1  [(, my, dear, child, of, the, world, …, ), \n\...
# 2  [Bismillah, hir, rahman, ir, rahim, ., \n, in,...
# 3  [his, Majesty, ,, \n, their, Highnesses, ,, \n...
# 4  [your, Majesties, ;, your, Royal, Highnesses, ...
#
#                                                  POS  \
# 0  [(PRON, PRP$), (PROPN, NNPS), (PUNCT, ,), (SPA...
# 1  [(PUNCT, -LRB-), (PRON, PRP$), (ADJ, JJ), (NOU...
# 2  [(PROPN, NNP), (PROPN, NNP), (PROPN, NNP), (PR...
# 3  [(PRON, PRP$), (PROPN, NNP), (PUNCT, ,), (SPAC...
# 4  [(PRON, PRP$), (PROPN, NNPS), (PUNCT, :), (PRO...
#
#                                         Proper_Nouns  \
# 0  [Majesties, Royal, Highness, Nobel, Committee,...
# 1  [Majesties, Royal, Highnesses, Excellencies, N...
# 2  [Bismillah, hir, rahman, ir, rahim, God, Majes...
# 3  [Majesty, Highnesses, Nobel, Committee, Ladies...
# 4  [Majesties, Royal, Highnesses, Nobel, Committe...
#
#                                       Named_Entities  \
# 0  [ORG, ORG, ORG, ORG, GPE, DATE, PERSON, ORG, O...
# 1  [ORG, ORG, PERSON, PERSON, PERSON, LOC, LOC, L...
# 2  [ORG, PERSON, ORG, DATE, DATE, ORG, ORG, PRODU...
# 3  [PERSON, ORG, WORK_OF_ART, ORG, ORG, ORG, ORG,...
# 4  [ORG, ORG, GPE, DATE, NORP, DATE, DATE, DATE, ...
#
#                                             NE_Words
# 0  [(Your, Royal, Highness), (the, Norwegian, Nob...
# 1  [(Excellencies), (the, Norwegian, Nobel, Commi...
# 2  [(Bismillah), (rahman, ir, rahim), (the, Norwe...
# 3  [(Majesty), (the, Nobel, Committee), (Ladies, ...
# 4  [(Royal, Highnesses), (the, Norwegian, Nobel, ...
